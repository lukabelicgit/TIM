# %%
import pandas as pd
df = pd.read_csv('adm_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.3 KB

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df = df.drop(columns=['Serial No.'])

# %%
dfcp = df.copy()

# %%
numerical_columns = dfcp.select_dtypes(include=['number']).columns

print(numerical_columns)
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
dfcp.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# ...

# %%
import matplotlib.pyplot as plt
for column in df.columns:
    plt.hist(dfcp[column], bins=20)
    plt.title(column)
    plt.show()

# %%
for column in df.columns:
    plt.scatter(range(len(df)), df[column], label=column, alpha=0.5)
    plt.title(column)
    plt.xlabel("Index")
    plt.ylabel("Feature Value")
    plt.legend()
    plt.show()

# %%
import seaborn as sns
import numpy as np
# Get the number of features
num_features = len(df.columns)

# Calculate the number of rows and columns for the subplot grid
num_rows = int(np.ceil(num_features / 2))
num_cols = 2

# Set the size of the plot
plt.figure(figsize=(12, 16))

# Iterate through each column in the DataFrame and create a box plot
for i, column in enumerate(df.columns):
    plt.subplot(num_rows, num_cols, i + 1)  # Adjust the subplot layout based on the number of features
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot for {column}')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dfcp[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %%
dfcp.describe()
# Out:
#           GRE Score   TOEFL Score  University Rating           SOP  \
# count  4.000000e+02  4.000000e+02       4.000000e+02  4.000000e+02
# mean  -4.174439e-16  5.595524e-16       7.105427e-17  7.993606e-17
# std    1.001252e+00  1.001252e+00       1.001252e+00  1.001252e+00
# min   -2.339367e+00 -2.542098e+00      -1.827457e+00 -2.386613e+00
# 25%   -7.685900e-01 -7.274920e-01      -9.520286e-01 -8.949798e-01
# 50%    1.679859e-02 -6.763531e-02      -7.660001e-02  9.944220e-02
# 75%    7.149218e-01  7.571856e-01       7.988286e-01  5.966532e-01
# max    2.023903e+00  2.076899e+00       1.674257e+00  1.591075e+00
#
#                LOR           CGPA      Research  Chance of Admit
# count  4.000000e+02  4.000000e+02  4.000000e+02      4.000000e+02
# mean  -1.332268e-16  7.771561e-16 -3.996803e-17     -3.375078e-16
# std    1.001252e+00  1.001252e+00  1.001252e+00      1.001252e+00
# min   -2.733036e+00 -3.020504e+00 -1.099975e+00     -2.698500e+00
# ...

# %%
dfcp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    float64
#  1   TOEFL Score        400 non-null    float64
#  2   University Rating  400 non-null    float64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    float64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(8)
# memory usage: 25.1 KB

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, :-1]
Y = df.iloc[:, -1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# Create the model
model = LinearRegression()

# Train the model
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
Y_pred = model.predict(X_test)
mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error: 0.047956733620911976
# Mean Squared Error: 0.004617003377285007
# R-squared: 0.8212082591486993

# %%
plt.scatter(Y_test, Y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted")
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'k--', lw=2)
plt.show()

# %%
from sklearn.model_selection import KFold
#K folds kros validacija
k = 5

kf = KFold(n_splits=k, shuffle=True, random_state=42)

mae_list = []
mse_list = []
r2_list = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]
    
    model = LinearRegression()
    model.fit(X_train, Y_train)
    
    Y_pred = model.predict(X_test)
    
    mae = mean_absolute_error(Y_test, Y_pred)
    mse = mean_squared_error(Y_test, Y_pred)
    r2 = r2_score(Y_test, Y_pred)
    
    mae_list.append(mae)
    mse_list.append(mse)
    r2_list.append(r2)

# Calculate the average metrics
avg_mae = np.mean(mae_list)
avg_mse = np.mean(mse_list)
avg_r2 = np.mean(r2_list)

print(f"Average Mean Absolute Error: {avg_mae}")
print(f"Average Mean Squared Error: {avg_mse}")
print(f"Average R-squared: {avg_r2}")
# Out:
# Average Mean Absolute Error: 0.046188985990243306
# Average Mean Squared Error: 0.004162825770797375
# Average R-squared: 0.7892564671561095
